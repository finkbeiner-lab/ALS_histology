# %%
"""
This code takes annotations from Qupath generated json files and create crops and annotation masks for each slide
""" 

import os
from os.path import exists
import glob
import json
import pdb
import numpy as np
from skimage import draw
import matplotlib.pyplot as plt
import argparse
import pyfiglet
from skimage import measure
from tqdm import tqdm
from PIL import Image
import pyvips as Vips
from concurrent.futures import ProcessPoolExecutor, as_completed
import cv2

# %%
# Mask size should be same as image size
ID_MASK_SHAPE = (512, 512)

## Color Coding
lablel2id = {'tdp43':'200', 'glial':'100'}
#             'Coarse-Grained':'150', 'CAA': '200', 'Unknown':'0'}

# Assign Dataset_path
#json_path = "/gladstone/finkbeiner/steve/work/data/ALS/annotations/fals-lumbar"
json_path = "/gladstone/finkbeiner/steve/work/data/ALS/annotations/sals-lumbar"
#WSI_path = "/gladstone/finkbeiner/steve/work/data/ALS/fals-lumbar"
WSI_path = "/gladstone/finkbeiner/steve/work/data/ALS/sals-lumbar"
#DATASET_PATH = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/ALS/all_crops/fals-lumbar"
DATASET_PATH = "/gladstone/finkbeiner/steve/work/data/npsad_data/monika/ALS/all_crops/sals-lumbar"

# %%
def save_img(img, file_name, tileX, tileY, label="mask"):
    """save image - use filename, tileX,tileY in the saved filename

    Args:
        img (np.array): numpy image to save
        file_name (string): filename (slide name)
        tileX (int): tile X coord
        tileY (int): tile Y coord
        label (str, optional): _description_. Defaults to "mask".
    """
    im = Image.fromarray(img)

    base_name_with_ext = os.path.basename(file_name)

    # Remove the extension to get the folder name
    folder_name = os.path.splitext(base_name_with_ext)[0]

    folder_name = os.path.join(DATASET_PATH, folder_name)

    # Create the new folder only if it does not exist
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    
     # Mask Folder
    save_dir = os.path.join(folder_name, label)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    file_name = file_name + "_" + str(tileX)+"x" + "_" + str(tileY) + "y" + "_" + label + ".png"

    save_name = os.path.join(save_dir, file_name)
    im.save(save_name)


def polygon2id(image_shape, mask, ids, coords_x, coords_y):
    """Draw polygon with x and y coords on mask with ids provided

    Args:
        image_shape (np.array): _description_
        mask (numpy array): _description_
        ids (string): _description_
        coords_x (np.array): X coordinates
        coords_y (np.array): Y coordinates

    Returns:
        np.array: mask 
    """
    vertex_row_coords, vertex_col_coords = coords_y, coords_x
    fill_row_coords, fill_col_coords = draw.polygon(
        vertex_row_coords, vertex_col_coords, image_shape)

    # Row and col are flipped
    mask[fill_col_coords, fill_row_coords] = ids
    return mask


def rectangle2id(image_shape, mask, ids, coords_x, coords_y):
    """
    Draw a rectangle on the mask using OpenCV.

    Args:
        image_shape (tuple): Shape of the image (height, width)
        mask (np.ndarray): Mask array where rectangle will be drawn
        ids (int or float): Value to fill inside the rectangle
        coords_x (np.ndarray): X coordinates (expects 2 points: [x_min, x_max])
        coords_y (np.ndarray): Y coordinates (expects 2 points: [y_min, y_max])

    Returns:
        np.ndarray: Updated mask with rectangle filled
    """
    # Ensure coordinates are in correct order
    x_min, x_max = int(np.min(coords_x)), int(np.max(coords_x))
    y_min, y_max = int(np.min(coords_y)), int(np.max(coords_y))

    # Draw filled rectangle on mask
    #cv2.rectangle(mask, (x_min, y_min), (x_max, y_max), color=ids, thickness=-1)
    mask[y_min:y_max, x_min:x_max] = ids

    return mask

def polygon2mask1(image_shape, mask, color, coords_x, coords_y):
    """Compute a mask with labels having different colors
    from polygon.
    Parameters
    ----------
    image_shape : tuple of size 2.
        The shape of the mask.
    coords_x: X coordinates
    coords_y: Y coordinates
    mask : Mask with same size of the image (initially empty
    mask is given as input)
    Returns
    -------
    mask : 2-D ndarray of type 'bool'.
        The mask that corresponds to the input polygon.
    """

    vertex_row_coords, vertex_col_coords = coords_x, coords_y
    fill_row_coords, fill_col_coords = draw.polygon(vertex_row_coords, vertex_col_coords, image_shape)

    # Row and col are flipped
    mask[fill_col_coords, fill_row_coords] = color
    return mask



def get_vips_info(vips_img):
    # # Get bounds-x and bounds-y offset
    vfields = [f.split('.') for f in vips_img.get_fields()]
    vfields = [f for f in vfields if f[0] == 'openslide']
    vfields = dict([('.'.join(k[1:]), vips_img.get('.'.join(k))) for k in vfields])
    return vfields


def process_single_image(img, json_path, visualize=False):
    """
    Processes a single image by extracting tiles and creating masks based on annotations in the corresponding JSON file.

    This function loads an image, extracts tiles based on the tile coordinates provided in a JSON file,
    generates masks for each tile based on region annotations, and saves the resulting images and masks.

    Args:
        img (str): The file path to the image that needs to be processed.
        json_path (str): The directory path where the corresponding JSON file is stored.
        visualize (bool): If set to True, displays the generated mask using matplotlib.

    Returns:
        None: This function does not return any value but saves processed images and masks to disk.
    """
    # Load the image using VIPS with level 0 to minimize memory usage
    vips_img = Vips.Image.new_from_file(img, level=0)
    
    # Extract metadata about the image
    vinfo = get_vips_info(vips_img)

    # Construct the corresponding JSON file path based on the image filename
    json_file_name = os.path.basename(img).split(".svs")[0] + ".json"
    json_file_name = os.path.join(json_path, json_file_name)

    # If the JSON file does not exist, exit the function
    if not exists(json_file_name):
        return

    print("Processing JSON file: ", json_file_name)

    # Open and load the JSON data
    with open(json_file_name) as f:
        data = json.load(f)

    # Iterate over each tile in the JSON data
    for tileId, ele in data.items():
        # Clean up tileId by removing square brackets
        tileId = tileId.replace("[", "").replace("]", "")
        
        # Parse the tile coordinates (tileX, tileY)
        tileX = int(tileId.split(",")[0])
        tileY = int(tileId.split(",")[1])
        
        # Define the size of each tile (1024x1024)
        tileWidth = 512
        tileHeight = 512

        # Adjust the tile coordinates based on the image's bounding box information
        tileX = (tileX * tileWidth) 
        tileY = (tileY * tileHeight) 

        # Crop the image using the calculated coordinates and tile size
        vips_img_crop = vips_img.crop(tileX, tileY, tileWidth, tileHeight)

        # Convert the cropped image to a numpy array
        vips_img_crop = np.ndarray(
            buffer=vips_img_crop.write_to_memory(), dtype=np.uint8,
            shape=(vips_img_crop.height, vips_img_crop.width, vips_img_crop.bands)
        )[..., :3]  # Keep only the RGB channels

        # Define the coordinates for the tile's bounding box
        x1 = tileX 
        x2 = tileX + tileWidth 
        y1 = tileY 
        y2 = tileY + tileHeight 
        
        print(x1,x2, y1,y2)

        # Initialize the mask (empty initially)
        id_mask = np.zeros(ID_MASK_SHAPE, dtype=np.uint8)

        # Iterate over the regions in the current tile's annotation data
        for region in ele:
            print(region)
            # Skip regions that don't contain a 'label' key
            if 'label' not in region.keys():
                continue
            
            low_X, lowY = region["region_attributes"][0]["roiBounds"]['XY']
            label_W, label_H = region["region_attributes"][0]["roiBounds"]['WH']
                
            coords_start =  [low_X, lowY]
            
            coords_end =  [low_X+label_W, lowY+label_H]
            
            #coords_x, coords_y = zip(*region["region_attributes"][0]['points'])
            
            coords_x, coords_y = [low_X-x1,low_X-x1+label_W], [lowY-y1,lowY-y1+label_H ]
            
            coords_x = np.array(coords_x)
            coords_y = np.array(coords_y)
            #coords_x = np.mod(coords_x, tileWidth)
            #coords_y = np.mod(coords_y, tileHeight)
            #print(coords_x)
            #print(coords_y)
            
            """
            # Extract coordinates of the polygon defining the region
            coords_x, coords_y = zip(*region["region_attributes"][0]['points'])
            coords_x = np.array(coords_x)
            coords_y = np.array(coords_y)

            # Skip regions that overlap with the tile boundaries
            if len(coords_x[coords_x > x2]) > 0:    #or len(coords_y[coords_y > y2]) > 0:
                print('Region overlaps with tile boundaries. Skipping region.')
                print("x2", x2)
                print("coords_x[coords_x > x2]", coords_x[coords_x > x2])
                print("coords_x",coords_x)
            if len(coords_y[coords_y > y2]) > 0: 
                print(coords_y[coords_y > y2])
                print(coords_y)
                

            # Adjust the coordinates to fit within the tile's boundary
            coords_x = np.mod(coords_x, tileWidth)
            coords_y = np.mod(coords_y, tileHeight)
            """
            # Get the label ID for the region
            label = region['label']
            ids = int(lablel2id[label])
            #print(ids)

            # Use the polygon2id function to create a mask for the region
            #id_mask = polygon2id(ID_MASK_SHAPE, id_mask, ids, coords_end,coords_start)
            #id_mask = polygon2id(ID_MASK_SHAPE, id_mask, ids, coords_y,coords_x)
            id_mask =rectangle2id(ID_MASK_SHAPE, id_mask, ids, coords_x, coords_y)

        # Generate the filename for saving the image and mask
        base_name = os.path.basename(img)
        file_name = os.path.splitext(base_name)[0]
        
        # Save the cropped image and the corresponding mask
        save_img(vips_img_crop, file_name, tileX, tileY, "image")
        save_img(id_mask, file_name, tileX, tileY, "mask")

        # Reset the mask for the next tile
        id_mask = np.zeros(ID_MASK_SHAPE, dtype=np.uint8)

    # If visualize flag is set to True, show the last generated mask using matplotlib
    if visualize:
        plt.imshow(id_mask)
        plt.show()



def process_json(WSI_path, json_path, visualize=False, max_workers=4):
    """This code does multiprocessing by calling process_single_image function on all slides

    Args:
        WSI_path (_type_): WSI file path
        json_path (_type_): Json file path
        visualize (bool, optional): true if need to visualize image. Defaults to False.
        max_workers (int, optional): max no of workers. Defaults to 4.
    """
    imagenames = glob.glob(os.path.join(WSI_path, "*.mrxs"))
    imagenames = sorted(imagenames)
    print(imagenames)
    plaque_dict = {'tdp43': 0, 'glial': 0}

    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_single_image, img, json_path, visualize) for img in imagenames]
        for future in as_completed(futures):
            future.result()


def merge_json(json_files, json_output_file=None):
    """
    merge_json: a method to return the combined json of a list of json files

    """
    result = list()
    for f1 in json_files:
        with open(f1, 'r') as infile:
            result.extend(json.load(infile))

    with open(json_output_file, 'w') as output_file:
        json.dump(result, output_file)

# %%
process_json(WSI_path, json_path, visualize=False, max_workers=12)
# Out:
# []

# %%
imagenames = glob.glob(os.path.join(WSI_path, "*.svs"))
imagenames = sorted(imagenames)

# %%
for i in range(len(imagenames)):
    img = imagenames[i]
    process_single_image( img, json_path, False)
# Out:
# Processing JSON file:  /gladstone/finkbeiner/steve/work/data/ALS/annotations/sals-lumbar/NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43.json
# 18944 19456 25600 26112
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19318, 25796], 'WH': [45, 52]}, 'points': [[19318.0, 25796.0], [19363.0, 25796.0], [19363.0, 25848.0], [19318.0, 25848.0]], 'tiles': [{'tileId': [37, 50], 'tileBounds': {'XY': [18944, 25600], 'WH': [512, 512]}}]}]}
# 18432 18944 25600 26112
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18645, 25690], 'WH': [67, 59]}, 'points': [[18645.0, 25690.0], [18712.0, 25690.0], [18712.0, 25749.0], [18645.0, 25749.0]], 'tiles': [{'tileId': [36, 50], 'tileBounds': {'XY': [18432, 25600], 'WH': [512, 512]}}]}]}
# 17920 18432 25088 25600
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17925, 25154], 'WH': [52, 48]}, 'points': [[17925.0, 25154.0], [17977.0, 25154.0], [17977.0, 25202.0], [17925.0, 25202.0]], 'tiles': [{'tileId': [35, 49], 'tileBounds': {'XY': [17920, 25088], 'WH': [512, 512]}}]}]}
# 18432 18944 24576 25088
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18562, 25042], 'WH': [69, 42]}, 'points': [[18562.0, 25042.0], [18631.0, 25042.0], [18631.0, 25084.0], [18562.0, 25084.0]], 'tiles': [{'tileId': [36, 48], 'tileBounds': {'XY': [18432, 24576], 'WH': [512, 512]}}]}]}
# 18432 18944 23552 24064
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18468, 23961], 'WH': [63, 55]}, 'points': [[18468.0, 23961.0], [18531.0, 23961.0], [18531.0, 24016.0], [18468.0, 24016.0]], 'tiles': [{'tileId': [36, 46], 'tileBounds': {'XY': [18432, 23552], 'WH': [512, 512]}}]}]}
# 19456 19968 24576 25088
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19533, 24602], 'WH': [61, 37]}, 'points': [[19533.0, 24602.0], [19594.0, 24602.0], [19594.0, 24639.0], [19533.0, 24639.0]], 'tiles': [{'tileId': [38, 48], 'tileBounds': {'XY': [19456, 24576], 'WH': [512, 512]}}]}]}
# 19968 20480 24064 24576
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20117, 24349], 'WH': [48, 43]}, 'points': [[20117.0, 24349.0], [20165.0, 24349.0], [20165.0, 24392.0], [20117.0, 24392.0]], 'tiles': [{'tileId': [39, 47], 'tileBounds': {'XY': [19968, 24064], 'WH': [512, 512]}}]}]}
# 18432 18944 23040 23552
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18915, 23176], 'WH': [143, 109]}, 'points': [[18986.5, 23176.0], [19058.0, 23230.5], [18986.5, 23285.0], [18915.0, 23230.5]], 'tiles': [{'tileId': [36, 45], 'tileBounds': {'XY': [18432, 23040], 'WH': [512, 512]}}, {'tileId': [37, 45], 'tileBounds': {'XY': [18944, 23040], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18605, 23044], 'WH': [161, 123]}, 'points': [[18685.5, 23044.0], [18766.0, 23105.5], [18685.5, 23167.0], [18605.0, 23105.5]], 'tiles': [{'tileId': [36, 45], 'tileBounds': {'XY': [18432, 23040], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18933, 23295], 'WH': [38, 36]}, 'points': [[18933.0, 23295.0], [18971.0, 23295.0], [18971.0, 23331.0], [18933.0, 23331.0]], 'tiles': [{'tileId': [36, 45], 'tileBounds': {'XY': [18432, 23040], 'WH': [512, 512]}}, {'tileId': [37, 45], 'tileBounds': {'XY': [18944, 23040], 'WH': [512, 512]}}]}]}
# 18944 19456 22528 23040
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18994, 23019], 'WH': [40, 31]}, 'points': [[18994.0, 23019.0], [19034.0, 23019.0], [19034.0, 23050.0], [18994.0, 23050.0]], 'tiles': [{'tileId': [37, 44], 'tileBounds': {'XY': [18944, 22528], 'WH': [512, 512]}}, {'tileId': [37, 45], 'tileBounds': {'XY': [18944, 23040], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19040, 22973], 'WH': [22, 31]}, 'points': [[19040.0, 22973.0], [19062.0, 22973.0], [19062.0, 23004.0], [19040.0, 23004.0]], 'tiles': [{'tileId': [37, 44], 'tileBounds': {'XY': [18944, 22528], 'WH': [512, 512]}}]}]}
# 18944 19456 23040 23552
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19346, 23415], 'WH': [48, 30]}, 'points': [[19346.0, 23415.0], [19394.0, 23415.0], [19394.0, 23445.0], [19346.0, 23445.0]], 'tiles': [{'tileId': [37, 45], 'tileBounds': {'XY': [18944, 23040], 'WH': [512, 512]}}]}]}
# 17408 17920 23040 23552
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17664, 23241], 'WH': [46, 50]}, 'points': [[17664.0, 23241.0], [17710.0, 23241.0], [17710.0, 23291.0], [17664.0, 23291.0]], 'tiles': [{'tileId': [34, 45], 'tileBounds': {'XY': [17408, 23040], 'WH': [512, 512]}}]}]}
# 16896 17408 22528 23040
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17331, 22898], 'WH': [59, 51]}, 'points': [[17331.0, 22898.0], [17390.0, 22898.0], [17390.0, 22949.0], [17331.0, 22949.0]], 'tiles': [{'tileId': [33, 44], 'tileBounds': {'XY': [16896, 22528], 'WH': [512, 512]}}]}]}
# 17408 17920 22528 23040
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17810, 22729], 'WH': [63, 66]}, 'points': [[17810.0, 22729.0], [17873.0, 22729.0], [17873.0, 22795.0], [17810.0, 22795.0]], 'tiles': [{'tileId': [34, 44], 'tileBounds': {'XY': [17408, 22528], 'WH': [512, 512]}}]}]}
# 17920 18432 22016 22528
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18180, 22178], 'WH': [154, 107]}, 'points': [[18257.0, 22178.0], [18334.0, 22231.5], [18257.0, 22285.0], [18180.0, 22231.5]], 'tiles': [{'tileId': [35, 43], 'tileBounds': {'XY': [17920, 22016], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18359, 22517], 'WH': [117, 106]}, 'points': [[18417.5, 22517.0], [18476.0, 22570.0], [18417.5, 22623.0], [18359.0, 22570.0]], 'tiles': [{'tileId': [35, 43], 'tileBounds': {'XY': [17920, 22016], 'WH': [512, 512]}}, {'tileId': [35, 44], 'tileBounds': {'XY': [17920, 22528], 'WH': [512, 512]}}, {'tileId': [36, 43], 'tileBounds': {'XY': [18432, 22016], 'WH': [512, 512]}}, {'tileId': [36, 44], 'tileBounds': {'XY': [18432, 22528], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18413, 22324], 'WH': [126, 99]}, 'points': [[18476.0, 22324.0], [18539.0, 22373.5], [18476.0, 22423.0], [18413.0, 22373.5]], 'tiles': [{'tileId': [35, 43], 'tileBounds': {'XY': [17920, 22016], 'WH': [512, 512]}}, {'tileId': [36, 43], 'tileBounds': {'XY': [18432, 22016], 'WH': [512, 512]}}]}]}
# 18432 18944 22016 22528
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18655, 22023], 'WH': [56, 40]}, 'points': [[18655.0, 22023.0], [18711.0, 22023.0], [18711.0, 22063.0], [18655.0, 22063.0]], 'tiles': [{'tileId': [36, 43], 'tileBounds': {'XY': [18432, 22016], 'WH': [512, 512]}}]}]}
# 19456 19968 22528 23040
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19504, 22704], 'WH': [56, 42]}, 'points': [[19504.0, 22704.0], [19560.0, 22704.0], [19560.0, 22746.0], [19504.0, 22746.0]], 'tiles': [{'tileId': [38, 44], 'tileBounds': {'XY': [19456, 22528], 'WH': [512, 512]}}]}]}
# 19968 20480 23040 23552
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20431, 23205], 'WH': [48, 40]}, 'points': [[20431.0, 23205.0], [20479.0, 23205.0], [20479.0, 23245.0], [20431.0, 23245.0]], 'tiles': [{'tileId': [39, 45], 'tileBounds': {'XY': [19968, 23040], 'WH': [512, 512]}}]}]}
# 19968 20480 21504 22016
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20210, 21636], 'WH': [77, 66]}, 'points': [[20210.0, 21636.0], [20287.0, 21636.0], [20287.0, 21702.0], [20210.0, 21702.0]], 'tiles': [{'tileId': [39, 42], 'tileBounds': {'XY': [19968, 21504], 'WH': [512, 512]}}]}]}
# 19968 20480 20992 21504
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20289, 21062], 'WH': [55, 42]}, 'points': [[20289.0, 21062.0], [20344.0, 21062.0], [20344.0, 21104.0], [20289.0, 21104.0]], 'tiles': [{'tileId': [39, 41], 'tileBounds': {'XY': [19968, 20992], 'WH': [512, 512]}}]}]}
# 19456 19968 20480 20992
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [19905, 20617], 'WH': [128, 126]}, 'points': [[19969.0, 20617.0], [20033.0, 20680.0], [19969.0, 20743.0], [19905.0, 20680.0]], 'tiles': [{'tileId': [38, 40], 'tileBounds': {'XY': [19456, 20480], 'WH': [512, 512]}}, {'tileId': [39, 40], 'tileBounds': {'XY': [19968, 20480], 'WH': [512, 512]}}]}]}
# 18944 19456 20480 20992
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19124, 20638], 'WH': [50, 54]}, 'points': [[19124.0, 20638.0], [19174.0, 20638.0], [19174.0, 20692.0], [19124.0, 20692.0]], 'tiles': [{'tileId': [37, 40], 'tileBounds': {'XY': [18944, 20480], 'WH': [512, 512]}}]}]}
# 17920 18432 19456 19968
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18326, 19917], 'WH': [53, 46]}, 'points': [[18326.0, 19917.0], [18379.0, 19917.0], [18379.0, 19963.0], [18326.0, 19963.0]], 'tiles': [{'tileId': [35, 38], 'tileBounds': {'XY': [17920, 19456], 'WH': [512, 512]}}]}]}
# 17408 17920 20480 20992
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17755, 20499], 'WH': [43, 42]}, 'points': [[17755.0, 20499.0], [17798.0, 20499.0], [17798.0, 20541.0], [17755.0, 20541.0]], 'tiles': [{'tileId': [34, 40], 'tileBounds': {'XY': [17408, 20480], 'WH': [512, 512]}}]}]}
# 16896 17408 18944 19456
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [16948, 19418], 'WH': [34, 35]}, 'points': [[16948.0, 19418.0], [16982.0, 19418.0], [16982.0, 19453.0], [16948.0, 19453.0]], 'tiles': [{'tileId': [33, 37], 'tileBounds': {'XY': [16896, 18944], 'WH': [512, 512]}}]}]}
# 16896 17408 18432 18944
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17404, 18715], 'WH': [67, 58]}, 'points': [[17404.0, 18715.0], [17471.0, 18715.0], [17471.0, 18773.0], [17404.0, 18773.0]], 'tiles': [{'tileId': [33, 36], 'tileBounds': {'XY': [16896, 18432], 'WH': [512, 512]}}, {'tileId': [34, 36], 'tileBounds': {'XY': [17408, 18432], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [17287, 18526], 'WH': [134, 160]}, 'points': [[17354.0, 18526.0], [17421.0, 18606.0], [17354.0, 18686.0], [17287.0, 18606.0]], 'tiles': [{'tileId': [33, 36], 'tileBounds': {'XY': [16896, 18432], 'WH': [512, 512]}}, {'tileId': [34, 36], 'tileBounds': {'XY': [17408, 18432], 'WH': [512, 512]}}]}]}
# 32256 32768 14848 15360
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32448, 15241], 'WH': [110, 116]}, 'points': [[32503.0, 15241.0], [32558.0, 15299.0], [32503.0, 15357.0], [32448.0, 15299.0]], 'tiles': [{'tileId': [63, 29], 'tileBounds': {'XY': [32256, 14848], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32659, 15123], 'WH': [146, 134]}, 'points': [[32732.0, 15123.0], [32805.0, 15190.0], [32732.0, 15257.0], [32659.0, 15190.0]], 'tiles': [{'tileId': [63, 29], 'tileBounds': {'XY': [32256, 14848], 'WH': [512, 512]}}, {'tileId': [64, 29], 'tileBounds': {'XY': [32768, 14848], 'WH': [512, 512]}}]}]}
# 32768 33280 14848 15360
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32980, 15210], 'WH': [138, 112]}, 'points': [[33049.0, 15210.0], [33118.0, 15266.0], [33049.0, 15322.0], [32980.0, 15266.0]], 'tiles': [{'tileId': [64, 29], 'tileBounds': {'XY': [32768, 14848], 'WH': [512, 512]}}]}]}
# 31744 32256 15872 16384
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32093, 16086], 'WH': [163, 163]}, 'points': [[32174.5, 16086.0], [32256.0, 16167.5], [32174.5, 16249.0], [32093.0, 16167.5]], 'tiles': [{'tileId': [62, 31], 'tileBounds': {'XY': [31744, 15872], 'WH': [512, 512]}}, {'tileId': [63, 31], 'tileBounds': {'XY': [32256, 15872], 'WH': [512, 512]}}]}]}
# 32768 33280 15872 16384
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32822, 16181], 'WH': [41, 43]}, 'points': [[32822.0, 16181.0], [32863.0, 16181.0], [32863.0, 16224.0], [32822.0, 16224.0]], 'tiles': [{'tileId': [64, 31], 'tileBounds': {'XY': [32768, 15872], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32989, 16170], 'WH': [47, 42]}, 'points': [[32989.0, 16170.0], [33036.0, 16170.0], [33036.0, 16212.0], [32989.0, 16212.0]], 'tiles': [{'tileId': [64, 31], 'tileBounds': {'XY': [32768, 15872], 'WH': [512, 512]}}]}]}
# 32768 33280 14336 14848
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [33084, 14796], 'WH': [220, 174]}, 'points': [[33194.0, 14796.0], [33304.0, 14883.0], [33194.0, 14970.0], [33084.0, 14883.0]], 'tiles': [{'tileId': [64, 28], 'tileBounds': {'XY': [32768, 14336], 'WH': [512, 512]}}, {'tileId': [64, 29], 'tileBounds': {'XY': [32768, 14848], 'WH': [512, 512]}}, {'tileId': [65, 28], 'tileBounds': {'XY': [33280, 14336], 'WH': [512, 512]}}, {'tileId': [65, 29], 'tileBounds': {'XY': [33280, 14848], 'WH': [512, 512]}}]}]}
# 32256 32768 14336 14848
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32597, 14779], 'WH': [191, 163]}, 'points': [[32692.5, 14779.0], [32788.0, 14860.5], [32692.5, 14942.0], [32597.0, 14860.5]], 'tiles': [{'tileId': [63, 28], 'tileBounds': {'XY': [32256, 14336], 'WH': [512, 512]}}, {'tileId': [63, 29], 'tileBounds': {'XY': [32256, 14848], 'WH': [512, 512]}}, {'tileId': [64, 28], 'tileBounds': {'XY': [32768, 14336], 'WH': [512, 512]}}, {'tileId': [64, 29], 'tileBounds': {'XY': [32768, 14848], 'WH': [512, 512]}}]}]}
# 32256 32768 13824 14336
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32695, 14333], 'WH': [121, 85]}, 'points': [[32755.5, 14333.0], [32816.0, 14375.5], [32755.5, 14418.0], [32695.0, 14375.5]], 'tiles': [{'tileId': [63, 27], 'tileBounds': {'XY': [32256, 13824], 'WH': [512, 512]}}, {'tileId': [63, 28], 'tileBounds': {'XY': [32256, 14336], 'WH': [512, 512]}}, {'tileId': [64, 27], 'tileBounds': {'XY': [32768, 13824], 'WH': [512, 512]}}, {'tileId': [64, 28], 'tileBounds': {'XY': [32768, 14336], 'WH': [512, 512]}}]}]}
# 33280 33792 13312 13824
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [33694, 13668], 'WH': [53, 48]}, 'points': [[33694.0, 13668.0], [33747.0, 13668.0], [33747.0, 13716.0], [33694.0, 13716.0]], 'tiles': [{'tileId': [65, 26], 'tileBounds': {'XY': [33280, 13312], 'WH': [512, 512]}}]}]}
# 33280 33792 13824 14336
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [33601, 13891], 'WH': [46, 57]}, 'points': [[33601.0, 13891.0], [33647.0, 13891.0], [33647.0, 13948.0], [33601.0, 13948.0]], 'tiles': [{'tileId': [65, 27], 'tileBounds': {'XY': [33280, 13824], 'WH': [512, 512]}}]}]}
# 32256 32768 13312 13824
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32582, 13735], 'WH': [56, 43]}, 'points': [[32582.0, 13735.0], [32638.0, 13735.0], [32638.0, 13778.0], [32582.0, 13778.0]], 'tiles': [{'tileId': [63, 26], 'tileBounds': {'XY': [32256, 13312], 'WH': [512, 512]}}]}]}
# 31232 31744 14336 14848
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [31331, 14549], 'WH': [50, 45]}, 'points': [[31331.0, 14549.0], [31381.0, 14549.0], [31381.0, 14594.0], [31331.0, 14594.0]], 'tiles': [{'tileId': [61, 28], 'tileBounds': {'XY': [31232, 14336], 'WH': [512, 512]}}]}]}
# 31232 31744 15360 15872
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [31467, 15829], 'WH': [57, 59]}, 'points': [[31467.0, 15829.0], [31524.0, 15829.0], [31524.0, 15888.0], [31467.0, 15888.0]], 'tiles': [{'tileId': [61, 30], 'tileBounds': {'XY': [31232, 15360], 'WH': [512, 512]}}, {'tileId': [61, 31], 'tileBounds': {'XY': [31232, 15872], 'WH': [512, 512]}}]}]}
# 30720 31232 15872 16384
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30760, 16143], 'WH': [65, 53]}, 'points': [[30760.0, 16143.0], [30825.0, 16143.0], [30825.0, 16196.0], [30760.0, 16196.0]], 'tiles': [{'tileId': [60, 31], 'tileBounds': {'XY': [30720, 15872], 'WH': [512, 512]}}]}]}
# 31232 31744 17408 17920
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [31658, 17440], 'WH': [48, 55]}, 'points': [[31658.0, 17440.0], [31706.0, 17440.0], [31706.0, 17495.0], [31658.0, 17495.0]], 'tiles': [{'tileId': [61, 34], 'tileBounds': {'XY': [31232, 17408], 'WH': [512, 512]}}]}]}
# 31744 32256 16896 17408
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32075, 17074], 'WH': [66, 60]}, 'points': [[32075.0, 17074.0], [32141.0, 17074.0], [32141.0, 17134.0], [32075.0, 17134.0]], 'tiles': [{'tileId': [62, 33], 'tileBounds': {'XY': [31744, 16896], 'WH': [512, 512]}}]}]}
# 29696 30208 17920 18432
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30180, 18128], 'WH': [55, 63]}, 'points': [[30180.0, 18128.0], [30235.0, 18128.0], [30235.0, 18191.0], [30180.0, 18191.0]], 'tiles': [{'tileId': [58, 35], 'tileBounds': {'XY': [29696, 17920], 'WH': [512, 512]}}, {'tileId': [59, 35], 'tileBounds': {'XY': [30208, 17920], 'WH': [512, 512]}}]}]}
# 31744 32256 19456 19968
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [32031, 19605], 'WH': [96, 103]}, 'points': [[32079.0, 19605.0], [32127.0, 19656.5], [32079.0, 19708.0], [32031.0, 19656.5]], 'tiles': [{'tileId': [62, 38], 'tileBounds': {'XY': [31744, 19456], 'WH': [512, 512]}}]}]}
# 31744 32256 19968 20480
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [31969, 20207], 'WH': [68, 48]}, 'points': [[31969.0, 20207.0], [32037.0, 20207.0], [32037.0, 20255.0], [31969.0, 20255.0]], 'tiles': [{'tileId': [62, 39], 'tileBounds': {'XY': [31744, 19968], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [31879, 20372], 'WH': [52, 51]}, 'points': [[31879.0, 20372.0], [31931.0, 20372.0], [31931.0, 20423.0], [31879.0, 20423.0]], 'tiles': [{'tileId': [62, 39], 'tileBounds': {'XY': [31744, 19968], 'WH': [512, 512]}}]}]}
# 35328 35840 17408 17920
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [35656, 17750], 'WH': [65, 63]}, 'points': [[35656.0, 17750.0], [35721.0, 17750.0], [35721.0, 17813.0], [35656.0, 17813.0]], 'tiles': [{'tileId': [69, 34], 'tileBounds': {'XY': [35328, 17408], 'WH': [512, 512]}}]}]}
# 36352 36864 15872 16384
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [36644, 16178], 'WH': [241, 199]}, 'points': [[36764.5, 16178.0], [36885.0, 16277.5], [36764.5, 16377.0], [36644.0, 16277.5]], 'tiles': [{'tileId': [71, 31], 'tileBounds': {'XY': [36352, 15872], 'WH': [512, 512]}}, {'tileId': [72, 31], 'tileBounds': {'XY': [36864, 15872], 'WH': [512, 512]}}]}]}
# 34816 35328 16384 16896
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [35085, 16465], 'WH': [151, 136]}, 'points': [[35160.5, 16465.0], [35236.0, 16533.0], [35160.5, 16601.0], [35085.0, 16533.0]], 'tiles': [{'tileId': [68, 32], 'tileBounds': {'XY': [34816, 16384], 'WH': [512, 512]}}]}]}
# 34816 35328 16896 17408
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [34873, 17277], 'WH': [66, 71]}, 'points': [[34873.0, 17277.0], [34939.0, 17277.0], [34939.0, 17348.0], [34873.0, 17348.0]], 'tiles': [{'tileId': [68, 33], 'tileBounds': {'XY': [34816, 16896], 'WH': [512, 512]}}]}]}
# 33280 33792 16896 17408
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [33499, 17084], 'WH': [63, 52]}, 'points': [[33499.0, 17084.0], [33562.0, 17084.0], [33562.0, 17136.0], [33499.0, 17136.0]], 'tiles': [{'tileId': [65, 33], 'tileBounds': {'XY': [33280, 16896], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [33457, 17001], 'WH': [47, 51]}, 'points': [[33457.0, 17001.0], [33504.0, 17001.0], [33504.0, 17052.0], [33457.0, 17052.0]], 'tiles': [{'tileId': [65, 33], 'tileBounds': {'XY': [33280, 16896], 'WH': [512, 512]}}]}]}
# 24576 25088 49152 49664
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [24990, 49297], 'WH': [245, 241]}, 'points': [[25112.5, 49297.0], [25235.0, 49417.5], [25112.5, 49538.0], [24990.0, 49417.5]], 'tiles': [{'tileId': [48, 96], 'tileBounds': {'XY': [24576, 49152], 'WH': [512, 512]}}, {'tileId': [49, 96], 'tileBounds': {'XY': [25088, 49152], 'WH': [512, 512]}}]}]}
# 26112 26624 48128 48640
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [26503, 48341], 'WH': [82, 69]}, 'points': [[26503.0, 48341.0], [26585.0, 48341.0], [26585.0, 48410.0], [26503.0, 48410.0]], 'tiles': [{'tileId': [51, 94], 'tileBounds': {'XY': [26112, 48128], 'WH': [512, 512]}}]}]}
# 25600 26112 47616 48128
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [26073, 48012], 'WH': [66, 53]}, 'points': [[26073.0, 48012.0], [26139.0, 48012.0], [26139.0, 48065.0], [26073.0, 48065.0]], 'tiles': [{'tileId': [50, 93], 'tileBounds': {'XY': [25600, 47616], 'WH': [512, 512]}}, {'tileId': [51, 93], 'tileBounds': {'XY': [26112, 47616], 'WH': [512, 512]}}]}]}
# 23552 24064 47616 48128
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [23761, 47647], 'WH': [66, 64]}, 'points': [[23761.0, 47647.0], [23827.0, 47647.0], [23827.0, 47711.0], [23761.0, 47711.0]], 'tiles': [{'tileId': [46, 93], 'tileBounds': {'XY': [23552, 47616], 'WH': [512, 512]}}]}]}
# 23040 23552 47104 47616
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [23257, 47504], 'WH': [44, 40]}, 'points': [[23257.0, 47504.0], [23301.0, 47504.0], [23301.0, 47544.0], [23257.0, 47544.0]], 'tiles': [{'tileId': [45, 92], 'tileBounds': {'XY': [23040, 47104], 'WH': [512, 512]}}]}]}
# 24576 25088 47616 48128
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [24769, 47878], 'WH': [101, 105]}, 'points': [[24819.5, 47878.0], [24870.0, 47930.5], [24819.5, 47983.0], [24769.0, 47930.5]], 'tiles': [{'tileId': [48, 93], 'tileBounds': {'XY': [24576, 47616], 'WH': [512, 512]}}]}]}
# 26112 26624 46592 47104
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [26279, 47082], 'WH': [168, 103]}, 'points': [[26363.0, 47082.0], [26447.0, 47133.5], [26363.0, 47185.0], [26279.0, 47133.5]], 'tiles': [{'tileId': [51, 91], 'tileBounds': {'XY': [26112, 46592], 'WH': [512, 512]}}, {'tileId': [51, 92], 'tileBounds': {'XY': [26112, 47104], 'WH': [512, 512]}}]}]}
# 30208 30720 46080 46592
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30315, 46417], 'WH': [41, 51]}, 'points': [[30315.0, 46417.0], [30356.0, 46417.0], [30356.0, 46468.0], [30315.0, 46468.0]], 'tiles': [{'tileId': [59, 90], 'tileBounds': {'XY': [30208, 46080], 'WH': [512, 512]}}]}]}
# 30208 30720 46592 47104
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30378, 47053], 'WH': [67, 56]}, 'points': [[30378.0, 47053.0], [30445.0, 47053.0], [30445.0, 47109.0], [30378.0, 47109.0]], 'tiles': [{'tileId': [59, 91], 'tileBounds': {'XY': [30208, 46592], 'WH': [512, 512]}}, {'tileId': [59, 92], 'tileBounds': {'XY': [30208, 47104], 'WH': [512, 512]}}]}]}
# 31232 31744 46080 46592
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [31243, 46306], 'WH': [93, 75]}, 'points': [[31289.5, 46306.0], [31336.0, 46343.5], [31289.5, 46381.0], [31243.0, 46343.5]], 'tiles': [{'tileId': [61, 90], 'tileBounds': {'XY': [31232, 46080], 'WH': [512, 512]}}]}]}
# 29184 29696 46080 46592
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [29369, 46399], 'WH': [204, 202]}, 'points': [[29471.0, 46399.0], [29573.0, 46500.0], [29471.0, 46601.0], [29369.0, 46500.0]], 'tiles': [{'tileId': [57, 90], 'tileBounds': {'XY': [29184, 46080], 'WH': [512, 512]}}, {'tileId': [57, 91], 'tileBounds': {'XY': [29184, 46592], 'WH': [512, 512]}}]}]}
# 28672 29184 46080 46592
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [28981, 46428], 'WH': [125, 129]}, 'points': [[29043.5, 46428.0], [29106.0, 46492.5], [29043.5, 46557.0], [28981.0, 46492.5]], 'tiles': [{'tileId': [56, 90], 'tileBounds': {'XY': [28672, 46080], 'WH': [512, 512]}}]}]}
# 28672 29184 46592 47104
# {'label': 'tdp43', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [28969, 46813], 'WH': [139, 113]}, 'points': [[29038.5, 46813.0], [29108.0, 46869.5], [29038.5, 46926.0], [28969.0, 46869.5]], 'tiles': [{'tileId': [56, 91], 'tileBounds': {'XY': [28672, 46592], 'WH': [512, 512]}}]}]}
# 32256 32768 47616 48128
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32471, 47663], 'WH': [82, 65]}, 'points': [[32471.0, 47663.0], [32553.0, 47663.0], [32553.0, 47728.0], [32471.0, 47728.0]], 'tiles': [{'tileId': [63, 93], 'tileBounds': {'XY': [32256, 47616], 'WH': [512, 512]}}]}]}
# 32768 33280 47104 47616
# {'label': 'glial', 'filename': 'NEUBD692FG6_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [32789, 47391], 'WH': [79, 81]}, 'points': [[32789.0, 47391.0], [32868.0, 47391.0], [32868.0, 47472.0], [32789.0, 47472.0]], 'tiles': [{'tileId': [64, 92], 'tileBounds': {'XY': [32768, 47104], 'WH': [512, 512]}}]}]}
# Processing JSON file:  /gladstone/finkbeiner/steve/work/data/ALS/annotations/sals-lumbar/NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43.json
# 18432 18944 40448 40960
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18507, 40827], 'WH': [213, 153]}, 'points': [[18613.5, 40827.0], [18720.0, 40903.5], [18613.5, 40980.0], [18507.0, 40903.5]], 'tiles': [{'tileId': [36, 79], 'tileBounds': {'XY': [18432, 40448], 'WH': [512, 512]}}, {'tileId': [36, 80], 'tileBounds': {'XY': [18432, 40960], 'WH': [512, 512]}}]}]}
# 18432 18944 38912 39424
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18497, 39237], 'WH': [137, 126]}, 'points': [[18565.5, 39237.0], [18634.0, 39300.0], [18565.5, 39363.0], [18497.0, 39300.0]], 'tiles': [{'tileId': [36, 76], 'tileBounds': {'XY': [18432, 38912], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18597, 39078], 'WH': [50, 51]}, 'points': [[18597.0, 39078.0], [18647.0, 39078.0], [18647.0, 39129.0], [18597.0, 39129.0]], 'tiles': [{'tileId': [36, 76], 'tileBounds': {'XY': [18432, 38912], 'WH': [512, 512]}}]}]}
# 20480 20992 38912 39424
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [20906, 38924], 'WH': [170, 167]}, 'points': [[20991.0, 38924.0], [21076.0, 39007.5], [20991.0, 39091.0], [20906.0, 39007.5]], 'tiles': [{'tileId': [40, 76], 'tileBounds': {'XY': [20480, 38912], 'WH': [512, 512]}}, {'tileId': [41, 76], 'tileBounds': {'XY': [20992, 38912], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20623, 39106], 'WH': [38, 53]}, 'points': [[20623.0, 39106.0], [20661.0, 39106.0], [20661.0, 39159.0], [20623.0, 39159.0]], 'tiles': [{'tileId': [40, 76], 'tileBounds': {'XY': [20480, 38912], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20740, 39054], 'WH': [54, 48]}, 'points': [[20740.0, 39054.0], [20794.0, 39054.0], [20794.0, 39102.0], [20740.0, 39102.0]], 'tiles': [{'tileId': [40, 76], 'tileBounds': {'XY': [20480, 38912], 'WH': [512, 512]}}]}]}
# 21504 22016 39424 39936
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [21562, 39879], 'WH': [156, 156]}, 'points': [[21640.0, 39879.0], [21718.0, 39957.0], [21640.0, 40035.0], [21562.0, 39957.0]], 'tiles': [{'tileId': [42, 77], 'tileBounds': {'XY': [21504, 39424], 'WH': [512, 512]}}, {'tileId': [42, 78], 'tileBounds': {'XY': [21504, 39936], 'WH': [512, 512]}}]}]}
# 17920 18432 39424 39936
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18040, 39515], 'WH': [54, 42]}, 'points': [[18040.0, 39515.0], [18094.0, 39515.0], [18094.0, 39557.0], [18040.0, 39557.0]], 'tiles': [{'tileId': [35, 77], 'tileBounds': {'XY': [17920, 39424], 'WH': [512, 512]}}]}]}
# 17408 17920 38912 39424
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17896, 39413], 'WH': [50, 51]}, 'points': [[17896.0, 39413.0], [17946.0, 39413.0], [17946.0, 39464.0], [17896.0, 39464.0]], 'tiles': [{'tileId': [34, 76], 'tileBounds': {'XY': [17408, 38912], 'WH': [512, 512]}}, {'tileId': [34, 77], 'tileBounds': {'XY': [17408, 39424], 'WH': [512, 512]}}, {'tileId': [35, 76], 'tileBounds': {'XY': [17920, 38912], 'WH': [512, 512]}}, {'tileId': [35, 77], 'tileBounds': {'XY': [17920, 39424], 'WH': [512, 512]}}]}]}
# 17920 18432 38400 38912
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18121, 38847], 'WH': [68, 39]}, 'points': [[18121.0, 38847.0], [18189.0, 38847.0], [18189.0, 38886.0], [18121.0, 38886.0]], 'tiles': [{'tileId': [35, 75], 'tileBounds': {'XY': [17920, 38400], 'WH': [512, 512]}}]}]}
# 18432 18944 38400 38912
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18478, 38694], 'WH': [75, 49]}, 'points': [[18478.0, 38694.0], [18553.0, 38694.0], [18553.0, 38743.0], [18478.0, 38743.0]], 'tiles': [{'tileId': [36, 75], 'tileBounds': {'XY': [18432, 38400], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18740, 38722], 'WH': [72, 64]}, 'points': [[18740.0, 38722.0], [18812.0, 38722.0], [18812.0, 38786.0], [18740.0, 38786.0]], 'tiles': [{'tileId': [36, 75], 'tileBounds': {'XY': [18432, 38400], 'WH': [512, 512]}}]}]}
# 19456 19968 39936 40448
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19765, 40102], 'WH': [67, 44]}, 'points': [[19765.0, 40102.0], [19832.0, 40102.0], [19832.0, 40146.0], [19765.0, 40146.0]], 'tiles': [{'tileId': [38, 78], 'tileBounds': {'XY': [19456, 39936], 'WH': [512, 512]}}]}]}
# 19968 20480 39936 40448
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20124, 40058], 'WH': [51, 44]}, 'points': [[20124.0, 40058.0], [20175.0, 40058.0], [20175.0, 40102.0], [20124.0, 40102.0]], 'tiles': [{'tileId': [39, 78], 'tileBounds': {'XY': [19968, 39936], 'WH': [512, 512]}}]}]}
# 19968 20480 39424 39936
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20011, 39891], 'WH': [55, 49]}, 'points': [[20011.0, 39891.0], [20066.0, 39891.0], [20066.0, 39940.0], [20011.0, 39940.0]], 'tiles': [{'tileId': [39, 77], 'tileBounds': {'XY': [19968, 39424], 'WH': [512, 512]}}, {'tileId': [39, 78], 'tileBounds': {'XY': [19968, 39936], 'WH': [512, 512]}}]}]}
# 20480 20992 38400 38912
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20905, 38721], 'WH': [66, 51]}, 'points': [[20905.0, 38721.0], [20971.0, 38721.0], [20971.0, 38772.0], [20905.0, 38772.0]], 'tiles': [{'tileId': [40, 75], 'tileBounds': {'XY': [20480, 38400], 'WH': [512, 512]}}]}]}
# 20480 20992 37376 37888
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [20900, 37429], 'WH': [76, 123]}, 'points': [[20938.0, 37429.0], [20976.0, 37490.5], [20938.0, 37552.0], [20900.0, 37490.5]], 'tiles': [{'tileId': [40, 73], 'tileBounds': {'XY': [20480, 37376], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20720, 37781], 'WH': [56, 56]}, 'points': [[20720.0, 37781.0], [20776.0, 37781.0], [20776.0, 37837.0], [20720.0, 37837.0]], 'tiles': [{'tileId': [40, 73], 'tileBounds': {'XY': [20480, 37376], 'WH': [512, 512]}}]}]}
# 20992 21504 37888 38400
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [21072, 38236], 'WH': [59, 53]}, 'points': [[21072.0, 38236.0], [21131.0, 38236.0], [21131.0, 38289.0], [21072.0, 38289.0]], 'tiles': [{'tileId': [41, 74], 'tileBounds': {'XY': [20992, 37888], 'WH': [512, 512]}}]}]}
# 19968 20480 37376 37888
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20251, 37885], 'WH': [59, 64]}, 'points': [[20251.0, 37885.0], [20310.0, 37885.0], [20310.0, 37949.0], [20251.0, 37949.0]], 'tiles': [{'tileId': [39, 73], 'tileBounds': {'XY': [19968, 37376], 'WH': [512, 512]}}, {'tileId': [39, 74], 'tileBounds': {'XY': [19968, 37888], 'WH': [512, 512]}}]}]}
# 20480 20992 36864 37376
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [20491, 36907], 'WH': [53, 54]}, 'points': [[20491.0, 36907.0], [20544.0, 36907.0], [20544.0, 36961.0], [20491.0, 36961.0]], 'tiles': [{'tileId': [40, 72], 'tileBounds': {'XY': [20480, 36864], 'WH': [512, 512]}}]}]}
# 19456 19968 36864 37376
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19948, 36949], 'WH': [70, 60]}, 'points': [[19948.0, 36949.0], [20018.0, 36949.0], [20018.0, 37009.0], [19948.0, 37009.0]], 'tiles': [{'tileId': [38, 72], 'tileBounds': {'XY': [19456, 36864], 'WH': [512, 512]}}, {'tileId': [39, 72], 'tileBounds': {'XY': [19968, 36864], 'WH': [512, 512]}}]}]}
# 18432 18944 37888 38400
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18614, 37989], 'WH': [52, 49]}, 'points': [[18614.0, 37989.0], [18666.0, 37989.0], [18666.0, 38038.0], [18614.0, 38038.0]], 'tiles': [{'tileId': [36, 74], 'tileBounds': {'XY': [18432, 37888], 'WH': [512, 512]}}]}]}
# 18944 19456 37376 37888
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [19049, 37727], 'WH': [50, 41]}, 'points': [[19049.0, 37727.0], [19099.0, 37727.0], [19099.0, 37768.0], [19049.0, 37768.0]], 'tiles': [{'tileId': [37, 73], 'tileBounds': {'XY': [18944, 37376], 'WH': [512, 512]}}]}]}
# 17920 18432 37376 37888
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18247, 37536], 'WH': [49, 44]}, 'points': [[18247.0, 37536.0], [18296.0, 37536.0], [18296.0, 37580.0], [18247.0, 37580.0]], 'tiles': [{'tileId': [35, 73], 'tileBounds': {'XY': [17920, 37376], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18137, 37426], 'WH': [59, 90]}, 'points': [[18137.0, 37426.0], [18196.0, 37426.0], [18196.0, 37516.0], [18137.0, 37516.0]], 'tiles': [{'tileId': [35, 73], 'tileBounds': {'XY': [17920, 37376], 'WH': [512, 512]}}]}]}
# 17408 17920 37888 38400
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17856, 38118], 'WH': [61, 52]}, 'points': [[17856.0, 38118.0], [17917.0, 38118.0], [17917.0, 38170.0], [17856.0, 38170.0]], 'tiles': [{'tileId': [34, 74], 'tileBounds': {'XY': [17408, 37888], 'WH': [512, 512]}}]}]}
# 16896 17408 36864 37376
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [17300, 37325], 'WH': [142, 97]}, 'points': [[17371.0, 37325.0], [17442.0, 37373.5], [17371.0, 37422.0], [17300.0, 37373.5]], 'tiles': [{'tileId': [33, 72], 'tileBounds': {'XY': [16896, 36864], 'WH': [512, 512]}}, {'tileId': [33, 73], 'tileBounds': {'XY': [16896, 37376], 'WH': [512, 512]}}, {'tileId': [34, 72], 'tileBounds': {'XY': [17408, 36864], 'WH': [512, 512]}}, {'tileId': [34, 73], 'tileBounds': {'XY': [17408, 37376], 'WH': [512, 512]}}]}]}
# 17920 18432 36864 37376
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18047, 37146], 'WH': [86, 96]}, 'points': [[18090.0, 37146.0], [18133.0, 37194.0], [18090.0, 37242.0], [18047.0, 37194.0]], 'tiles': [{'tileId': [35, 72], 'tileBounds': {'XY': [17920, 36864], 'WH': [512, 512]}}]}]}
# 16896 17408 36352 36864
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17206, 36813], 'WH': [61, 56]}, 'points': [[17206.0, 36813.0], [17267.0, 36813.0], [17267.0, 36869.0], [17206.0, 36869.0]], 'tiles': [{'tileId': [33, 71], 'tileBounds': {'XY': [16896, 36352], 'WH': [512, 512]}}, {'tileId': [33, 72], 'tileBounds': {'XY': [16896, 36864], 'WH': [512, 512]}}]}]}
# 17408 17920 36352 36864
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17712, 36836], 'WH': [46, 51]}, 'points': [[17712.0, 36836.0], [17758.0, 36836.0], [17758.0, 36887.0], [17712.0, 36887.0]], 'tiles': [{'tileId': [34, 71], 'tileBounds': {'XY': [17408, 36352], 'WH': [512, 512]}}, {'tileId': [34, 72], 'tileBounds': {'XY': [17408, 36864], 'WH': [512, 512]}}]}]}
# 18432 18944 36352 36864
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18601, 36687], 'WH': [54, 46]}, 'points': [[18601.0, 36687.0], [18655.0, 36687.0], [18655.0, 36733.0], [18601.0, 36733.0]], 'tiles': [{'tileId': [36, 71], 'tileBounds': {'XY': [18432, 36352], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18715, 36811], 'WH': [102, 104]}, 'points': [[18766.0, 36811.0], [18817.0, 36863.0], [18766.0, 36915.0], [18715.0, 36863.0]], 'tiles': [{'tileId': [36, 71], 'tileBounds': {'XY': [18432, 36352], 'WH': [512, 512]}}, {'tileId': [36, 72], 'tileBounds': {'XY': [18432, 36864], 'WH': [512, 512]}}]}]}
# 17920 18432 35328 35840
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [17935, 35646], 'WH': [51, 41]}, 'points': [[17935.0, 35646.0], [17986.0, 35646.0], [17986.0, 35687.0], [17935.0, 35687.0]], 'tiles': [{'tileId': [35, 69], 'tileBounds': {'XY': [17920, 35328], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18132, 35710], 'WH': [49, 59]}, 'points': [[18132.0, 35710.0], [18181.0, 35710.0], [18181.0, 35769.0], [18132.0, 35769.0]], 'tiles': [{'tileId': [35, 69], 'tileBounds': {'XY': [17920, 35328], 'WH': [512, 512]}}]}]}
# 17920 18432 34304 34816
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18417, 34683], 'WH': [88, 65]}, 'points': [[18417.0, 34683.0], [18505.0, 34683.0], [18505.0, 34748.0], [18417.0, 34748.0]], 'tiles': [{'tileId': [35, 67], 'tileBounds': {'XY': [17920, 34304], 'WH': [512, 512]}}, {'tileId': [36, 67], 'tileBounds': {'XY': [18432, 34304], 'WH': [512, 512]}}]}]}
# 18432 18944 34816 35328
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [18669, 34831], 'WH': [102, 125]}, 'points': [[18720.0, 34831.0], [18771.0, 34893.5], [18720.0, 34956.0], [18669.0, 34893.5]], 'tiles': [{'tileId': [36, 68], 'tileBounds': {'XY': [18432, 34816], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18635, 35316], 'WH': [46, 49]}, 'points': [[18635.0, 35316.0], [18681.0, 35316.0], [18681.0, 35365.0], [18635.0, 35365.0]], 'tiles': [{'tileId': [36, 68], 'tileBounds': {'XY': [18432, 34816], 'WH': [512, 512]}}, {'tileId': [36, 69], 'tileBounds': {'XY': [18432, 35328], 'WH': [512, 512]}}]}]}
# 18944 19456 34816 35328
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18968, 35304], 'WH': [52, 51]}, 'points': [[18968.0, 35304.0], [19020.0, 35304.0], [19020.0, 35355.0], [18968.0, 35355.0]], 'tiles': [{'tileId': [37, 68], 'tileBounds': {'XY': [18944, 34816], 'WH': [512, 512]}}, {'tileId': [37, 69], 'tileBounds': {'XY': [18944, 35328], 'WH': [512, 512]}}]}]}
# 17408 17920 34304 34816
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [17874, 34477], 'WH': [132, 97]}, 'points': [[17940.0, 34477.0], [18006.0, 34525.5], [17940.0, 34574.0], [17874.0, 34525.5]], 'tiles': [{'tileId': [34, 67], 'tileBounds': {'XY': [17408, 34304], 'WH': [512, 512]}}, {'tileId': [35, 67], 'tileBounds': {'XY': [17920, 34304], 'WH': [512, 512]}}]}]}
# 16896 17408 33792 34304
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [17292, 34200], 'WH': [102, 83]}, 'points': [[17343.0, 34200.0], [17394.0, 34241.5], [17343.0, 34283.0], [17292.0, 34241.5]], 'tiles': [{'tileId': [33, 66], 'tileBounds': {'XY': [16896, 33792], 'WH': [512, 512]}}]}]}
# 16896 17408 34816 35328
# {'label': 'tdp43', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [17067, 35052], 'WH': [64, 80]}, 'points': [[17099.0, 35052.0], [17131.0, 35092.0], [17099.0, 35132.0], [17067.0, 35092.0]], 'tiles': [{'tileId': [33, 68], 'tileBounds': {'XY': [16896, 34816], 'WH': [512, 512]}}]}]}
# 16384 16896 34304 34816
# {'label': 'glial', 'filename': 'NEUBU920EK5_Spinal_Cord_Lumbar2_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [16614, 34416], 'WH': [43, 51]}, 'points': [[16614.0, 34416.0], [16657.0, 34416.0], [16657.0, 34467.0], [16614.0, 34467.0]], 'tiles': [{'tileId': [32, 67], 'tileBounds': {'XY': [16384, 34304], 'WH': [512, 512]}}]}]}
# ...
# 25600 26112 17920 18432
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [26074, 18379], 'WH': [242, 208]}, 'points': [[26195.0, 18379.0], [26316.0, 18483.0], [26195.0, 18587.0], [26074.0, 18483.0]], 'tiles': [{'tileId': [50, 35], 'tileBounds': {'XY': [25600, 17920], 'WH': [512, 512]}}, {'tileId': [50, 36], 'tileBounds': {'XY': [25600, 18432], 'WH': [512, 512]}}, {'tileId': [51, 35], 'tileBounds': {'XY': [26112, 17920], 'WH': [512, 512]}}, {'tileId': [51, 36], 'tileBounds': {'XY': [26112, 18432], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [25715, 18314], 'WH': [191, 222]}, 'points': [[25810.5, 18314.0], [25906.0, 18425.0], [25810.5, 18536.0], [25715.0, 18425.0]], 'tiles': [{'tileId': [50, 35], 'tileBounds': {'XY': [25600, 17920], 'WH': [512, 512]}}, {'tileId': [50, 36], 'tileBounds': {'XY': [25600, 18432], 'WH': [512, 512]}}]}]}
# 26624 27136 18944 19456
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [26632, 18976], 'WH': [415, 302]}, 'points': [[26839.5, 18976.0], [27047.0, 19127.0], [26839.5, 19278.0], [26632.0, 19127.0]], 'tiles': [{'tileId': [52, 37], 'tileBounds': {'XY': [26624, 18944], 'WH': [512, 512]}}]}]}
# 23552 24064 17920 18432
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [23743, 18033], 'WH': [109, 104]}, 'points': [[23797.5, 18033.0], [23852.0, 18085.0], [23797.5, 18137.0], [23743.0, 18085.0]], 'tiles': [{'tileId': [46, 35], 'tileBounds': {'XY': [23552, 17920], 'WH': [512, 512]}}]}]}
# 26624 27136 17408 17920
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [26988, 17598], 'WH': [180, 180]}, 'points': [[27078.0, 17598.0], [27168.0, 17688.0], [27078.0, 17778.0], [26988.0, 17688.0]], 'tiles': [{'tileId': [52, 34], 'tileBounds': {'XY': [26624, 17408], 'WH': [512, 512]}}, {'tileId': [53, 34], 'tileBounds': {'XY': [27136, 17408], 'WH': [512, 512]}}]}]}
# 25600 26112 16384 16896
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [25933, 16846], 'WH': [124, 103]}, 'points': [[25995.0, 16846.0], [26057.0, 16897.5], [25995.0, 16949.0], [25933.0, 16897.5]], 'tiles': [{'tileId': [50, 32], 'tileBounds': {'XY': [25600, 16384], 'WH': [512, 512]}}, {'tileId': [50, 33], 'tileBounds': {'XY': [25600, 16896], 'WH': [512, 512]}}]}]}
# 25088 25600 15872 16384
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [25385, 16105], 'WH': [192, 222]}, 'points': [[25481.0, 16105.0], [25577.0, 16216.0], [25481.0, 16327.0], [25385.0, 16216.0]], 'tiles': [{'tileId': [49, 31], 'tileBounds': {'XY': [25088, 15872], 'WH': [512, 512]}}]}]}
# 27136 27648 14336 14848
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [27419, 14816], 'WH': [254, 246]}, 'points': [[27546.0, 14816.0], [27673.0, 14939.0], [27546.0, 15062.0], [27419.0, 14939.0]], 'tiles': [{'tileId': [53, 28], 'tileBounds': {'XY': [27136, 14336], 'WH': [512, 512]}}, {'tileId': [53, 29], 'tileBounds': {'XY': [27136, 14848], 'WH': [512, 512]}}, {'tileId': [54, 28], 'tileBounds': {'XY': [27648, 14336], 'WH': [512, 512]}}, {'tileId': [54, 29], 'tileBounds': {'XY': [27648, 14848], 'WH': [512, 512]}}]}]}
# 27136 27648 14848 15360
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [27458, 15211], 'WH': [205, 148]}, 'points': [[27560.5, 15211.0], [27663.0, 15285.0], [27560.5, 15359.0], [27458.0, 15285.0]], 'tiles': [{'tileId': [53, 29], 'tileBounds': {'XY': [27136, 14848], 'WH': [512, 512]}}, {'tileId': [54, 29], 'tileBounds': {'XY': [27648, 14848], 'WH': [512, 512]}}]}]}
# 28672 29184 14336 14848
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [29122, 14686], 'WH': [42, 43]}, 'points': [[29122.0, 14686.0], [29164.0, 14686.0], [29164.0, 14729.0], [29122.0, 14729.0]], 'tiles': [{'tileId': [56, 28], 'tileBounds': {'XY': [28672, 14336], 'WH': [512, 512]}}]}]}
# 29184 29696 14336 14848
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [29589, 14716], 'WH': [38, 46]}, 'points': [[29589.0, 14716.0], [29627.0, 14716.0], [29627.0, 14762.0], [29589.0, 14762.0]], 'tiles': [{'tileId': [57, 28], 'tileBounds': {'XY': [29184, 14336], 'WH': [512, 512]}}]}]}
# 30208 30720 14336 14848
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30338, 14712], 'WH': [53, 55]}, 'points': [[30338.0, 14712.0], [30391.0, 14712.0], [30391.0, 14767.0], [30338.0, 14767.0]], 'tiles': [{'tileId': [59, 28], 'tileBounds': {'XY': [30208, 14336], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30640, 14687], 'WH': [30, 33]}, 'points': [[30640.0, 14687.0], [30670.0, 14687.0], [30670.0, 14720.0], [30640.0, 14720.0]], 'tiles': [{'tileId': [59, 28], 'tileBounds': {'XY': [30208, 14336], 'WH': [512, 512]}}]}]}
# 30720 31232 14336 14848
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [30908, 14688], 'WH': [37, 38]}, 'points': [[30908.0, 14688.0], [30945.0, 14688.0], [30945.0, 14726.0], [30908.0, 14726.0]], 'tiles': [{'tileId': [60, 28], 'tileBounds': {'XY': [30720, 14336], 'WH': [512, 512]}}]}]}
# 29184 29696 15872 16384
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [29556, 16212], 'WH': [57, 50]}, 'points': [[29556.0, 16212.0], [29613.0, 16212.0], [29613.0, 16262.0], [29556.0, 16262.0]], 'tiles': [{'tileId': [57, 31], 'tileBounds': {'XY': [29184, 15872], 'WH': [512, 512]}}]}]}
# 29184 29696 17408 17920
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [29439, 17591], 'WH': [56, 51]}, 'points': [[29439.0, 17591.0], [29495.0, 17591.0], [29495.0, 17642.0], [29439.0, 17642.0]], 'tiles': [{'tileId': [57, 34], 'tileBounds': {'XY': [29184, 17408], 'WH': [512, 512]}}]}]}
# 27648 28160 16896 17408
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [27919, 17083], 'WH': [69, 58]}, 'points': [[27919.0, 17083.0], [27988.0, 17083.0], [27988.0, 17141.0], [27919.0, 17141.0]], 'tiles': [{'tileId': [54, 33], 'tileBounds': {'XY': [27648, 16896], 'WH': [512, 512]}}]}]}
# 27136 27648 16896 17408
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [27625, 17173], 'WH': [52, 42]}, 'points': [[27625.0, 17173.0], [27677.0, 17173.0], [27677.0, 17215.0], [27625.0, 17215.0]], 'tiles': [{'tileId': [53, 33], 'tileBounds': {'XY': [27136, 16896], 'WH': [512, 512]}}, {'tileId': [54, 33], 'tileBounds': {'XY': [27648, 16896], 'WH': [512, 512]}}]}]}
# 49664 50176 12288 12800
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [49823, 12302], 'WH': [80, 87]}, 'points': [[49863.0, 12302.0], [49903.0, 12345.5], [49863.0, 12389.0], [49823.0, 12345.5]], 'tiles': [{'tileId': [97, 24], 'tileBounds': {'XY': [49664, 12288], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [49968, 12512], 'WH': [69, 57]}, 'points': [[49968.0, 12512.0], [50037.0, 12512.0], [50037.0, 12569.0], [49968.0, 12569.0]], 'tiles': [{'tileId': [97, 24], 'tileBounds': {'XY': [49664, 12288], 'WH': [512, 512]}}]}]}
# 50176 50688 10752 11264
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [50637, 11139], 'WH': [113, 161]}, 'points': [[50693.5, 11139.0], [50750.0, 11219.5], [50693.5, 11300.0], [50637.0, 11219.5]], 'tiles': [{'tileId': [98, 21], 'tileBounds': {'XY': [50176, 10752], 'WH': [512, 512]}}, {'tileId': [98, 22], 'tileBounds': {'XY': [50176, 11264], 'WH': [512, 512]}}, {'tileId': [99, 21], 'tileBounds': {'XY': [50688, 10752], 'WH': [512, 512]}}, {'tileId': [99, 22], 'tileBounds': {'XY': [50688, 11264], 'WH': [512, 512]}}]}]}
# 51200 51712 10752 11264
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [51554, 10832], 'WH': [100, 98]}, 'points': [[51604.0, 10832.0], [51654.0, 10881.0], [51604.0, 10930.0], [51554.0, 10881.0]], 'tiles': [{'tileId': [100, 21], 'tileBounds': {'XY': [51200, 10752], 'WH': [512, 512]}}]}]}
# 50688 51200 8192 8704
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [50717, 8379], 'WH': [250, 184]}, 'points': [[50842.0, 8379.0], [50967.0, 8471.0], [50842.0, 8563.0], [50717.0, 8471.0]], 'tiles': [{'tileId': [99, 16], 'tileBounds': {'XY': [50688, 8192], 'WH': [512, 512]}}]}]}
# 52736 53248 9728 10240
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [52793, 9738], 'WH': [60, 65]}, 'points': [[52793.0, 9738.0], [52853.0, 9738.0], [52853.0, 9803.0], [52793.0, 9803.0]], 'tiles': [{'tileId': [103, 19], 'tileBounds': {'XY': [52736, 9728], 'WH': [512, 512]}}]}]}
# 55808 56320 12288 12800
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [55948, 12430], 'WH': [139, 142]}, 'points': [[56017.5, 12430.0], [56087.0, 12501.0], [56017.5, 12572.0], [55948.0, 12501.0]], 'tiles': [{'tileId': [109, 24], 'tileBounds': {'XY': [55808, 12288], 'WH': [512, 512]}}]}]}
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [56007, 12738], 'WH': [84, 101]}, 'points': [[56049.0, 12738.0], [56091.0, 12788.5], [56049.0, 12839.0], [56007.0, 12788.5]], 'tiles': [{'tileId': [109, 24], 'tileBounds': {'XY': [55808, 12288], 'WH': [512, 512]}}, {'tileId': [109, 25], 'tileBounds': {'XY': [55808, 12800], 'WH': [512, 512]}}]}]}
# 55808 56320 11264 11776
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [56236, 11266], 'WH': [44, 52]}, 'points': [[56236.0, 11266.0], [56280.0, 11266.0], [56280.0, 11318.0], [56236.0, 11318.0]], 'tiles': [{'tileId': [109, 22], 'tileBounds': {'XY': [55808, 11264], 'WH': [512, 512]}}]}]}
# 56320 56832 11264 11776
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [56682, 11386], 'WH': [49, 51]}, 'points': [[56682.0, 11386.0], [56731.0, 11386.0], [56731.0, 11437.0], [56682.0, 11437.0]], 'tiles': [{'tileId': [110, 22], 'tileBounds': {'XY': [56320, 11264], 'WH': [512, 512]}}]}]}
# 56832 57344 10240 10752
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [57103, 10688], 'WH': [358, 327]}, 'points': [[57282.0, 10688.0], [57461.0, 10851.5], [57282.0, 11015.0], [57103.0, 10851.5]], 'tiles': [{'tileId': [111, 20], 'tileBounds': {'XY': [56832, 10240], 'WH': [512, 512]}}, {'tileId': [111, 21], 'tileBounds': {'XY': [56832, 10752], 'WH': [512, 512]}}, {'tileId': [112, 20], 'tileBounds': {'XY': [57344, 10240], 'WH': [512, 512]}}, {'tileId': [112, 21], 'tileBounds': {'XY': [57344, 10752], 'WH': [512, 512]}}]}]}
# 57856 58368 9728 10240
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [58157, 10088], 'WH': [133, 164]}, 'points': [[58223.5, 10088.0], [58290.0, 10170.0], [58223.5, 10252.0], [58157.0, 10170.0]], 'tiles': [{'tileId': [113, 19], 'tileBounds': {'XY': [57856, 9728], 'WH': [512, 512]}}, {'tileId': [113, 20], 'tileBounds': {'XY': [57856, 10240], 'WH': [512, 512]}}]}]}
# 57856 58368 10240 10752
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [58294, 10674], 'WH': [97, 90]}, 'points': [[58342.5, 10674.0], [58391.0, 10719.0], [58342.5, 10764.0], [58294.0, 10719.0]], 'tiles': [{'tileId': [113, 20], 'tileBounds': {'XY': [57856, 10240], 'WH': [512, 512]}}, {'tileId': [113, 21], 'tileBounds': {'XY': [57856, 10752], 'WH': [512, 512]}}, {'tileId': [114, 20], 'tileBounds': {'XY': [58368, 10240], 'WH': [512, 512]}}, {'tileId': [114, 21], 'tileBounds': {'XY': [58368, 10752], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [58079, 10604], 'WH': [38, 32]}, 'points': [[58079.0, 10604.0], [58117.0, 10604.0], [58117.0, 10636.0], [58079.0, 10636.0]], 'tiles': [{'tileId': [113, 20], 'tileBounds': {'XY': [57856, 10240], 'WH': [512, 512]}}]}]}
# 17920 18432 18944 19456
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [18366, 19111], 'WH': [78, 73]}, 'points': [[18366.0, 19111.0], [18444.0, 19111.0], [18444.0, 19184.0], [18366.0, 19184.0]], 'tiles': [{'tileId': [35, 37], 'tileBounds': {'XY': [17920, 18944], 'WH': [512, 512]}}, {'tileId': [36, 37], 'tileBounds': {'XY': [18432, 18944], 'WH': [512, 512]}}]}]}
# 18944 19456 18944 19456
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [19037, 19451], 'WH': [173, 164]}, 'points': [[19123.5, 19451.0], [19210.0, 19533.0], [19123.5, 19615.0], [19037.0, 19533.0]], 'tiles': [{'tileId': [37, 37], 'tileBounds': {'XY': [18944, 18944], 'WH': [512, 512]}}, {'tileId': [37, 38], 'tileBounds': {'XY': [18944, 19456], 'WH': [512, 512]}}]}]}
# 15872 16384 20480 20992
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [16172, 20959], 'WH': [189, 164]}, 'points': [[16266.5, 20959.0], [16361.0, 21041.0], [16266.5, 21123.0], [16172.0, 21041.0]], 'tiles': [{'tileId': [31, 40], 'tileBounds': {'XY': [15872, 20480], 'WH': [512, 512]}}, {'tileId': [31, 41], 'tileBounds': {'XY': [15872, 20992], 'WH': [512, 512]}}]}]}
# 15360 15872 21504 22016
# {'label': 'tdp43', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Ellipse', 'region_attributes': [{'roiBounds': {'XY': [15813, 21702], 'WH': [146, 96]}, 'points': [[15886.0, 21702.0], [15959.0, 21750.0], [15886.0, 21798.0], [15813.0, 21750.0]], 'tiles': [{'tileId': [30, 42], 'tileBounds': {'XY': [15360, 21504], 'WH': [512, 512]}}, {'tileId': [31, 42], 'tileBounds': {'XY': [15872, 21504], 'WH': [512, 512]}}]}]}
# {'label': 'glial', 'filename': 'NEUFF179PPT_Spinal_Cord_Lumbar_pTDP_43', 'roiName': 'Rectangle', 'region_attributes': [{'roiBounds': {'XY': [15418, 21742], 'WH': [43, 33]}, 'points': [[15418.0, 21742.0], [15461.0, 21742.0], [15461.0, 21775.0], [15418.0, 21775.0]], 'tiles': [{'tileId': [30, 42], 'tileBounds': {'XY': [15360, 21504], 'WH': [512, 512]}}]}]}
